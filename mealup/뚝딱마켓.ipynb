# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import urllib.request as req
import urllib.parse as pa
from bs4 import BeautifulSoup as bs
import time
from urllib.parse import quote

# %%
# url = 'https://www.tuktakmarket.com/product/list.html?cate_no=30' # 양식
url = 'https://www.tuktakmarket.com/product/list.html?cate_no=29' # 한식

resp = req.urlopen(url).read().decode('utf-8')
# print(resp)

soup = bs(resp, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "//www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
#
# <html lang="ko" xml:lang="ko" xmlns="//www.w3.org/1999/xhtml"><head><script>
# (function(i, s, o, g, r, a, m) {
#     a = s.createElement(o);
#     m = s.getElementsByTagName(o)[0];
#     a.src = g;
#     a.onload = function() {
#         i[r].init('https://js-error-tracer-api.cafe24.com', {"token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..CZ9uq6hCHHnOJ5f0HRteCZNlnZbtguVX5zojWP_WWIo","collectWindowErrors":true,"preventDuplicateReport":true,"storageKeyPrefix":"EC_JET.PRODUCT_LIST"});
#     };
#     m.parentNode.insertBefore(a, m);
# ...

# %%
aa = soup.select('div > ul > li.item div.prdImg > a > img')
# aa = soup.select('div.item_cont')
ss = soup.select('div.item_info_cont')
제목 = soup.select('div.description > strong.name > a span')#.next_sibling.next_sibling
가격 = soup.select('span.price')
image = []
# for i in aa:
#     image.append(i['src'][2:])
    
title = []
price = []
for i in 가격:
    price.append(i.text)
    # print(i.text)
# print(len(aa))
for i in 제목:
    
    if i.text[0] == '상':
        pass
    else :
        title.append(i.text)
# print(가격)
    
for i in aa:
    # print(i['src'])
    str_text = 'https:' + i['src']
    image.append(str_text)
    print(str_text)

# %% [markdown]
# ## 데이터 프레임 만들기

# %%
meal_sample = pd.DataFrame({
    'title' : title,
    'price' : price,
    'image' : image
}, index=range(1, len(aa)+1))

# %%
meal_sample.to_excel('양식.xlsx',index=False)
##

# %% [markdown]
# ## 이미지 저장

# %%
import urllib.request
import time

# 다운받을 이미지 url
for i, d in enumerate(image):
    url = i

    # time check
    start = time.time()

    # 이미지 요청 및 다운로드
    str_aa = '양식/양식{}.jpg'.format(i+1)
    print(str_aa)
    print(d)
    urllib.request.urlretrieve(image[i], str_aa)

#     # 이미지 다운로드 시간 체크
    # print(time.time() - start)

    # 저장 된 이미지 확인
    # img = Image.open("test.jpg")

# %% [markdown]
# ## 상세 페이지 들어가기

# %%
detail_item = soup.select('div > div.prdImg > a')
print(len(detail_item))
# Out:
# 20

# %%
url_all = []
for i in detail_item:
    str_list = 'https://www.tuktakmarket.com' + quote(i['href'])
    url_all.append(str_list)

# %%
len(url_all)
# Out:
# 20

# %%
# detail_itemimg = []

asd = [] # 인코딩 저장할곳
for a in url_all:
    resp = req.urlopen(a).read().decode('utf-8')
    soup = bs(resp, 'html.parser')
    dd = soup.select('div> div> div.continner > img')
    cc = soup.select('div.cont > div > p > img')
    detail_itemimg = [] # 저장할곳
    
    if len(dd) > 1:
        detail_itemimg.append([dd[0]])
        # print(detail_itemimg.append(dd[0]))
    else:
        detail_itemimg.append(dd)
        # print(detail_itemimg.append(dd))
        
    if len(cc) > 1:
        detail_itemimg.append([cc[2]])
        # print(detail_itemimg.append(cc[2]))
    elif len(cc) == 2:
        detail_itemimg.append([cc[0]])
        # print(detail_itemimg.append(cc[0]))
    else:
        detail_itemimg.append(cc)
        # print(detail_itemimg.append(cc))
        
    for i in detail_itemimg:
        for j in i:
            asd.append(j['ec-data-src'])
    
    
    # for i in cc:
    #     print(i['ec-data-src'])
    # if True != dd:
    #     dd = soup.select('div.cont > div > p > img')
    #     for i in dd:
    #         detail_itemimg.append(i['ec-data-src'])
    # else:
    #     for i in dd:
    #         detail_itemimg.append(i['ec-data-src'])
    #     dd = soup.select('div.cont > div > img')
    #     for i in dd:
    #         detail_itemimg.append(i['ec-data-src'])

# %%
ssd = [] # 인코딩 한거 저장
for i in asd:
    if i[1] == '혼' or i[1] == '밀' or i[1] == '김':
        i = quote(i)
    ssd.append(i)

# %%
ssd
# Out:
# ['/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EB%AA%85%EC%A0%88%20%EA%B0%88%EB%B9%84%EC%84%A0%EB%AC%BC%EC%84%B8%ED%8A%B8%20%EC%83%81%EC%84%B82.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%B9%98%ED%82%A8%EB%84%88%EA%B2%9F%20%EC%83%81%EC%84%B8.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%ED%8F%AC%ED%81%AC%EB%84%88%EA%B2%9F%20%EC%83%81%EC%84%B8.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%A7%81%ED%99%94%EB%AC%B4%EB%BC%88%EB%B6%88%EB%8B%AD%EB%B0%9C%20%EC%83%81%EC%84%B8.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%88%98%EC%A0%9C%EB%96%A1%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8-1.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/LA%20%EC%96%91%EB%85%90%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%84%A4%EB%A0%81%ED%83%95%20%EC%83%81%EC%84%B8.jpg',
#  '/%ED%98%BC%EB%B0%A5%EC%8B%9D%EB%8B%B9/%EB%91%90%EB%A3%A8%EC%B9%98%EA%B8%B0%20%EC%83%81%EC%84%B8%202%ED%8C%A9.jpg',
#  '/%ED%98%BC%EB%B0%A5%EC%8B%9D%EB%8B%B9/%EA%B9%80%EC%B9%98%EC%B0%8C%EA%B0%9C%202%ED%8C%A9.jpg',
# ...

# %% [markdown]
# ## 테스트

# %%
url = 'https://www.tuktakmarket.com/product/%EA%BD%89%EC%B0%AC-%EC%95%8C%ED%83%95-700g/40/category/29/display/1/'

resp = req.urlopen(url).read().decode('utf-8')
# print(resp)

soup = bs(resp, 'html.parser')
# print(soup)

# %%
aa = soup.select('div.cont > div > img')
# for i in dd:
#     print(i['ec-data-src'])
# print(aa[0]['ec-data-src'])
# if 1 < len(aa):
#     print(aa[2])
print(aa)
# Out:
# [<img alt="" ec-data-src="/%ED%95%B4%EC%84%AC/%EC%95%8C%ED%83%95-re1.jpg"/>, <img alt="" ec-data-src="/%ED%95%B4%EC%84%AC/%EC%95%8C%ED%83%95-2.jpg"/>]

# %%
ssd.insert(19,aa[0]['ec-data-src'])

# %%
ssd.pop(1)
# Out:
# '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%B9%98%ED%82%A8%EB%84%88%EA%B2%9F%20%EC%83%81%EC%84%B8.jpg'

# %%
ssd
# Out:
# ['/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EB%AA%85%EC%A0%88%20%EA%B0%88%EB%B9%84%EC%84%A0%EB%AC%BC%EC%84%B8%ED%8A%B8%20%EC%83%81%EC%84%B82.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%ED%8F%AC%ED%81%AC%EB%84%88%EA%B2%9F%20%EC%83%81%EC%84%B8.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%A7%81%ED%99%94%EB%AC%B4%EB%BC%88%EB%B6%88%EB%8B%AD%EB%B0%9C%20%EC%83%81%EC%84%B8.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%88%98%EC%A0%9C%EB%96%A1%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8-1.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/LA%20%EC%96%91%EB%85%90%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8.jpg',
#  '/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%84%A4%EB%A0%81%ED%83%95%20%EC%83%81%EC%84%B8.jpg',
#  '/%ED%98%BC%EB%B0%A5%EC%8B%9D%EB%8B%B9/%EB%91%90%EB%A3%A8%EC%B9%98%EA%B8%B0%20%EC%83%81%EC%84%B8%202%ED%8C%A9.jpg',
#  '/%ED%98%BC%EB%B0%A5%EC%8B%9D%EB%8B%B9/%EA%B9%80%EC%B9%98%EC%B0%8C%EA%B0%9C%202%ED%8C%A9.jpg',
#  '/%ED%95%B4%EC%84%AC/%EB%8C%80%EA%B5%AC%ED%83%95%20%EC%83%81%EC%84%B8%ED%8E%98%EC%9D%B4%EC%A7%80-re.jpg',
# ...

# %% [markdown]
# ## 저장하기

# %%
image = []
for i in ssd:
    # print(i['src'])
    str_text = 'https://www.tuktakmarket.com' + i # 인코딩 때문
    image.append(str_text)
    print(str_text)
# Out:
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EB%AA%85%EC%A0%88%20%EA%B0%88%EB%B9%84%EC%84%A0%EB%AC%BC%EC%84%B8%ED%8A%B8%20%EC%83%81%EC%84%B82.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%ED%8F%AC%ED%81%AC%EB%84%88%EA%B2%9F%20%EC%83%81%EC%84%B8.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%A7%81%ED%99%94%EB%AC%B4%EB%BC%88%EB%B6%88%EB%8B%AD%EB%B0%9C%20%EC%83%81%EC%84%B8.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%88%98%EC%A0%9C%EB%96%A1%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8-1.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/LA%20%EC%96%91%EB%85%90%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%84%A4%EB%A0%81%ED%83%95%20%EC%83%81%EC%84%B8.jpg
# https://www.tuktakmarket.com/%ED%98%BC%EB%B0%A5%EC%8B%9D%EB%8B%B9/%EB%91%90%EB%A3%A8%EC%B9%98%EA%B8%B0%20%EC%83%81%EC%84%B8%202%ED%8C%A9.jpg
# ...

# %%
len(image)
# Out:
# 20

# %%
import urllib.request
import time

# 다운받을 이미지 url
for i, d in enumerate(image):
    url = i

    # time check
    start = time.time()

    # 이미지 요청 및 다운로드
    str_aa = '한식/한식상세/한식{}.jpg'.format(i+1)
    print(str_aa)
    print(d)
    urllib.request.urlretrieve(image[i], str_aa)

#     # 이미지 다운로드 시간 체크
    # print(time.time() - start)

    # 저장 된 이미지 확인
    # img = Image.open("test.jpg")
# Out:
# 한식/한식상세/한식1.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EB%AA%85%EC%A0%88%20%EA%B0%88%EB%B9%84%EC%84%A0%EB%AC%BC%EC%84%B8%ED%8A%B8%20%EC%83%81%EC%84%B82.jpg
# 한식/한식상세/한식2.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%ED%8F%AC%ED%81%AC%EB%84%88%EA%B2%9F%20%EC%83%81%EC%84%B8.jpg
# 한식/한식상세/한식3.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%A7%81%ED%99%94%EB%AC%B4%EB%BC%88%EB%B6%88%EB%8B%AD%EB%B0%9C%20%EC%83%81%EC%84%B8.jpg
# 한식/한식상세/한식4.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%88%98%EC%A0%9C%EB%96%A1%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8-1.jpg
# 한식/한식상세/한식5.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/LA%20%EC%96%91%EB%85%90%EA%B0%88%EB%B9%84%20%EC%83%81%EC%84%B8.jpg
# 한식/한식상세/한식6.jpg
# https://www.tuktakmarket.com/BBQ%EC%95%84%EC%A0%80%EC%94%A8/%EC%84%A4%EB%A0%81%ED%83%95%20%EC%83%81%EC%84%B8.jpg
# 한식/한식상세/한식7.jpg
# ...

# %%
brower = webdriver.Chrome('C:\\BigData\\chromedriver.exe')
url = 'https://www.tuktakmarket.com/product/list.html?cate_no=29#none'
# Out:
# C:\Users\dbsal\AppData\Local\Temp/ipykernel_38144/329328736.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   brower = webdriver.Chrome('C:\\BigData\\chromedriver.exe')

# %%
brower.get(url_all[0])

# %%
# brower.find_element_by_css_selector('div.box > button').click()
# # brower.find_element_by_css_selector('div.sub_menu_box_all_btn > a').click()
# brower.find_element_by_css_selector('ul.sub_depth1 > a').click()

# %%
quote('프리미엄-la양념갈비-선물세트-')
# Out:
# '%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84-la%EC%96%91%EB%85%90%EA%B0%88%EB%B9%84-%EC%84%A0%EB%AC%BC%EC%84%B8%ED%8A%B8-'

# %%
# %ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84-la%EC%96%91%EB%85%90%EA%B0%88%EB%B9%84-%EC%84%A0%EB%AC%BC%EC%84%B8%ED%8A%B8-

# %%
quote('%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84-la%EC%96%91%EB%85%90%EA%B0%88%EB%B9%84-%EC%84%A0%EB%AC%BC%EC%84%B8%ED%8A%B8-2kg/334/category/29/display/1/')
# Out:
# '%25ED%2594%2584%25EB%25A6%25AC%25EB%25AF%25B8%25EC%2597%2584-la%25EC%2596%2591%25EB%2585%2590%25EA%25B0%2588%25EB%25B9%2584-%25EC%2584%25A0%25EB%25AC%25BC%25EC%2584%25B8%25ED%258A%25B8-2kg/334/category/29/display/1/'

# %% [markdown]
# # 양식

# %%
url = 'https://www.tuktakmarket.com/product/list.html?cate_no=30'
resp = req.urlopen(url).read().decode('utf-8')
soup = bs(resp, 'html.parser')
# print(soup)

# %%
detail_item = soup.select('div > div.prdImg > a')
# print(len(detail_item))
# print(detail_item)

# %%
url_all = []
for i in detail_item:
    # print(i['href'])
    i['href'] = quote(i['href'])
    url_all.append('https://www.tuktakmarket.com'+i['href'])

# %%
url = 'https://www.tuktakmarket.com/product/%EB%B2%A0%EC%9D%B4%EC%BB%A8-%ED%8A%B8%EB%9F%AC%ED%94%8C-%ED%81%AC%EB%A6%BC-%ED%8C%8C%EC%8A%A4%ED%83%80-480g/346/category/30/display/1/'
resp = req.urlopen(url).read().decode('utf-8')
soup = bs(resp, 'html.parser')

# %%
soup.select('div.cont > div > img')
# Out:
# [<img ec-data-src="/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%8A%B8%EB%9F%AC%ED%94%8C%ED%81%AC%EB%A6%BC-%ED%8C%8C%EC%8A%A4%ED%83%80-%EC%83%81%EC%84%B8.jpg" style="display: block; vertical-align: top; margin: 0px auto; text-align: center;"/>]

# %%
item = []
for i in url_all:
    resp = req.urlopen(i).read().decode('utf-8')
    soup = bs(resp, 'html.parser')
    list_img = soup.select('div.cont > div > img')
    list_img1 = soup.select('div.cont > div > div > p > img')
    list_img2 = soup.select('div.cont > div > p > img')
    # print(list_img)
    # print(list_img1)
    # print(list_img2)
    item.append(list_img)
    item.append(list_img1)
    item.append(list_img2)

# %%
url_all

# %%
item주소 = []
for i in item:
    for f in i:
        if f['ec-data-src'][1] == '아' :
            f['ec-data-src'] = quote(f['ec-data-src'])
            str_list = 'https://www.tuktakmarket.com' + f['ec-data-src']
            item주소.append(str_list)
        else:
            str_list = 'https://www.tuktakmarket.com' + f['ec-data-src']
            item주소.append(str_list)
        # print()
        # print()

# %%
item주소
# Out:
# ['https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%95%B4%EC%82%B0%EB%AC%BC-%ED%86%A0%EB%A7%88%ED%86%A0-%EC%8A%A4%ED%8A%9C-%EC%83%81%EC%84%B8.jpg',
#  'https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%EC%89%AC%EB%A6%BC%ED%94%84%ED%88%AC%EC%9B%80%EB%B0%94-%EC%83%81%EC%84%B8%ED%8E%98%EC%9D%B4%EC%A7%80.jpg',
#  'https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%8A%B8%EB%9F%AC%ED%94%8C%ED%81%AC%EB%A6%BC-%ED%8C%8C%EC%8A%A4%ED%83%80-%EC%83%81%EC%84%B8.jpg',
#  'https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%95%A0%EB%9D%BC%ED%94%BC%EB%87%A8-%ED%81%AC%EB%A6%BC-%EC%83%81%EC%84%B8.jpg',
#  'https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%95%B4%EC%82%B0%EB%AC%BC-%EC%98%A4%EC%9D%BC-%ED%8C%8C%EC%8A%A4%ED%83%80-%EC%83%81%EC%84%B8.jpg',
#  'https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%EB%A1%9C%EC%A0%9C-%EC%83%81%EC%84%B8%ED%8E%98%EC%9D%B4%EC%A7%80.jpg',
# ...

# %%
import urllib.request
import time

for i, d in enumerate(item주소):
    num = i
    str_aa = '양식/양식상세/양식{}.jpg'.format(i+1)
    print(str_aa)
    print(d)
    urllib.request.urlretrieve(item주소[i], str_aa)
# Out:
# 양식/양식상세/양식1.jpg
# https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%95%B4%EC%82%B0%EB%AC%BC-%ED%86%A0%EB%A7%88%ED%86%A0-%EC%8A%A4%ED%8A%9C-%EC%83%81%EC%84%B8.jpg
# 양식/양식상세/양식2.jpg
# https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%EC%89%AC%EB%A6%BC%ED%94%84%ED%88%AC%EC%9B%80%EB%B0%94-%EC%83%81%EC%84%B8%ED%8E%98%EC%9D%B4%EC%A7%80.jpg
# 양식/양식상세/양식3.jpg
# https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%8A%B8%EB%9F%AC%ED%94%8C%ED%81%AC%EB%A6%BC-%ED%8C%8C%EC%8A%A4%ED%83%80-%EC%83%81%EC%84%B8.jpg
# 양식/양식상세/양식4.jpg
# https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%95%A0%EB%9D%BC%ED%94%BC%EB%87%A8-%ED%81%AC%EB%A6%BC-%EC%83%81%EC%84%B8.jpg
# 양식/양식상세/양식5.jpg
# https://www.tuktakmarket.com/%EC%BF%A0%EC%BF%A0%EC%B9%98%EB%82%98/%ED%95%B4%EC%82%B0%EB%AC%BC-%EC%98%A4%EC%9D%BC-%ED%8C%8C%EC%8A%A4%ED%83%80-%EC%83%81%EC%84%B8.jpg
# 양식/양식상세/양식6.jpg
# ...

# %%
import urllib.request
import time

# 다운받을 이미지 url
for i, d in enumerate(image):
    url = i

    # time check
    start = time.time()

    # 이미지 요청 및 다운로드
    str_aa = '한식/한식상세/한식{}.jpg'.format(i+1)
    print(str_aa)
    print(d)
    urllib.request.urlretrieve(image[i], str_aa)

#     # 이미지 다운로드 시간 체크
    # print(time.time() - start)

    # 저장 된 이미지 확인
    # img = Image.open("test.jpg")
